# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/ProfAI/machine-learning-fondamenti/main/datasets/shirts.csv"
df = pd.read_csv(url,index_col=0)
df.head()
# Out:
#   taglia  colore  prezzo
# 0      S  bianco    4.99
# 1      M  bianco   19.99
# 2     XL  bianco   12.49
# 3     XL  bianco   14.99
# 4      S  bianco   14.99

# %%
url = "https://raw.githubusercontent.com/ProfAI/machine-learning-fondamenti/main/datasets/shirts_example.tsv"
df = pd.read_csv(url,index_col=0,sep="\t")
df.head()
# Out:
#   taglia  colore  prezzo
# 0      S  bianco    4.99
# 1      M  bianco   19.99
# 2     XL  bianco   12.49
# 3     XL  bianco   14.99
# 4      S  bianco   14.99

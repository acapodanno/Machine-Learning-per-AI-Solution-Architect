# %% [markdown]
# <a href="https://colab.research.google.com/github/acapodanno/Machine-Learning-per-AI-Solution-Architect/blob/main/linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

class LinearRegression:
  bias_ = 0
  weigth_ = 0
  def fit(self, x, y):
    x_np = np.array(x)
    y_np = np.array(y)
    sum_x = np.sum(x_np)
    sum_y = np.sum(y_np)
    sum_x2 = np.sum(x_np**2)
    sum_xy = np.sum(x_np*y_np)

# %%
x =  [80,150,30,50,120,60,110,110]
y = [ 16,30,12,10,24,18,20,25]

linear_regression = LinearRegression()
linear_regression.fit(x,y)

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/ProfAI/machine-learning-fondamenti/main/datasets/shirts_example.json"
df = pd.read_json(url)
df.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 url = "https://raw.githubusercontent.com/ProfAI/machine-learning-fondamenti/main/datasets/shirts_example.json"
# ----> 2 df = pd.read_json(url,index_col=0)
#       3 df.head()
#
# TypeError: read_json() got an unexpected keyword argument 'index_col'
